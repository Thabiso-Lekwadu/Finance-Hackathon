# %%
from graphdatascience import GraphDataScience

host = "neo4j://127.0.0.1:7687"
user = "neo4j"
password= "Lekwadu@1"

gds = GraphDataScience(host, auth=(user, password))

print(gds.version())
# Out:
# Unable to retrieve routing information
# Transaction failed and will be retried in 1.0980119756902966s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 2.2256199344776224s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 4.000680512360451s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 6.620228307253418s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 14.964632072854771s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 34.76946753412165s (Unable to retrieve routing information)
# Unable to retrieve routing information
# ---------------------------------------------------------------------------
# ExceptionGroup                            Traceback (most recent call last)
# ExceptionGroup: All routing table requests failed (1 sub-exception)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:323, in Neo4jQueryRunner.server_version(self)
#     322 try:
# --> 323     server_version_string = self.call_function("gds.version", query_type=QueryType.SYSTEM, custom_error=False)
#     324     server_version = ServerVersion.from_string(server_version_string)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:279, in Neo4jQueryRunner.call_function(self, endpoint, query_type, params, custom_error)
#     278 # we can use retryable cypher as we expect all gds functions to be idempotent
# --> 279 return self.run_retryable_cypher(
#     280     query, query_type, params, custom_error=custom_error, mode=QueryMode.READ
#     281 ).squeeze()
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:265, in Neo4jQueryRunner.run_retryable_cypher(self, query, query_type, params, database, mode, custom_error, connectivity_retry_config)
#     264 else:
# --> 265     raise e
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:248, in Neo4jQueryRunner.run_retryable_cypher(self, query, query_type, params, database, mode, custom_error, connectivity_retry_config)
#     246 bookmark_manager = neo4j.GraphDatabase.bookmark_manager(self.bookmarks())
# --> 248 result = self._driver.execute_query(
#     249     query_=self._wrap_query(query, query_type),
#     250     parameters_=params,
#     251     database_=database,
#     252     result_transformer_=neo4j.Result.to_df,
#     253     bookmark_manager_=bookmark_manager,
#     254     routing_=routing,
#     255 )
#     257 self._last_bookmarks = neo4j.Bookmarks.from_raw_values(bookmark_manager.get_bookmarks())
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\driver.py:950, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     949 with session._pipelined_begin:
# --> 950     return session._run_transaction(
#     951         access_mode,
#     952         TelemetryAPI.DRIVER,
#     953         work,
#     954         (query_str, parameters, result_transformer_),
#     955         {},
#     956     )
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:618, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     615 if errors:
#     616     # TODO: 7.0 - when Python 3.11+ is the minimum,
#     617     #             use exception groups
# --> 618     raise errors[-1]
#     619 else:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:566, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     565 try:
# --> 566     self._open_transaction(
#     567         tx_cls=ManagedTransaction,
#     568         api=None if telemetry_sent else api,
#     569         access_mode=access_mode,
#     570         metadata=metadata,
#     571         timeout=timeout,
#     572         api_success_cb=api_success_cb,
#     573     )
#     574     assert isinstance(self._transaction, ManagedTransaction)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:432, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     422 def _open_transaction(
#     423     self,
#     424     *,
#    (...)    430     api_success_cb: t.Callable[[dict], None] | None = None,
#     431 ) -> None:
# --> 432     self._connect(access_mode=access_mode)
#     433     assert self._connection is not None
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:128, in Session._connect(self, access_mode, **acquire_kwargs)
#     127 try:
# --> 128     super()._connect(
#     129         access_mode, auth=self._config.auth, **acquire_kwargs
#     130     )
#     131 except asyncio.CancelledError:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:166, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     165 ssr_enabled = self._pool.ssr_enabled
# --> 166 target_db = self._get_routing_target_database(
#     167     acquire_auth,
#     168     ssr_enabled=ssr_enabled,
#     169     acquisition_deadline=acquisition_deadline,
#     170 )
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:244, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled, acquisition_deadline)
#     243 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 244 self._pool.update_routing_table(
#     245     database=self._config.database,
#     246     imp_user=self._config.impersonated_user,
#     247     bookmarks=self._get_bookmarks(),
#     248     auth=acquire_auth,
#     249     acquisition_timeout=acquisition_deadline,
#     250     database_callback=self._make_db_resolution_callback(),
#     251 )
#     252 return AcquisitionDatabase(self._config.database)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:1076, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1075         e = error
# -> 1076 raise ServiceUnavailable(
#    1077     "Unable to retrieve routing information"
#    1078 ) from e
#
# ServiceUnavailable: Unable to retrieve routing information
#
# During handling of the above exception, another exception occurred:
#
# UnableToConnectError                      Traceback (most recent call last)
# Cell In[2], line 7
#       3 host = "neo4j://127.0.0.1:7687"
#       4 user = "neo4j"
#       5 password= "Lekwadu@1"
#       6
# ----> 7 gds = GraphDataScience(host, auth=(user, password))
#       8
#       9 print(gds.version())
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\graph_data_science.py:105, in GraphDataScience.__init__(self, endpoint, auth, aura_ds, database, arrow, arrow_disable_server_verification, arrow_tls_root_certs, bookmarks, show_progress, arrow_client_options)
#     100     neo4j_query_runner = Neo4jQueryRunner.create_for_db(
#     101         endpoint, db_auth, aura_ds, database, bookmarks, show_progress
#     102     )
#     103     self._query_runner = neo4j_query_runner
# --> 105 self._server_version = self._query_runner.server_version()
#     107 if self._server_version < ServerVersion.from_string(__min_server_version__):
#     108     warnings.warn(
#     109         DeprecationWarning(
#     110             f"Client does not support the given server version `{self._server_version}`."
#    (...)    113         )
#     114     )
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:339, in Neo4jQueryRunner.server_version(self)
#     331     self.close()
#     333     raise GdsNotFound(
#     334         f"""The Graph Data Science library is not correctly installed on the {self._instance_description}.
#     335         Please refer to https://neo4j.com/docs/graph-data-science/current/installation/.
#     336         """
#     337     )
# --> 339 raise UnableToConnectError(e)
#
# UnableToConnectError: Unable to retrieve routing information

# %%
from graphdatascience import GraphDataScience

host = "neo4j://127.0.0.1:7687"
user = "neo4j"
password= "pleaseletmein"

gds = GraphDataScience(host, auth=(user, password))

print(gds.version())
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:323, in Neo4jQueryRunner.server_version(self)
#     322 try:
# --> 323     server_version_string = self.call_function("gds.version", query_type=QueryType.SYSTEM, custom_error=False)
#     324     server_version = ServerVersion.from_string(server_version_string)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:279, in Neo4jQueryRunner.call_function(self, endpoint, query_type, params, custom_error)
#     278 # we can use retryable cypher as we expect all gds functions to be idempotent
# --> 279 return self.run_retryable_cypher(
#     280     query, query_type, params, custom_error=custom_error, mode=QueryMode.READ
#     281 ).squeeze()
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:265, in Neo4jQueryRunner.run_retryable_cypher(self, query, query_type, params, database, mode, custom_error, connectivity_retry_config)
#     264 else:
# --> 265     raise e
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:248, in Neo4jQueryRunner.run_retryable_cypher(self, query, query_type, params, database, mode, custom_error, connectivity_retry_config)
#     246 bookmark_manager = neo4j.GraphDatabase.bookmark_manager(self.bookmarks())
# --> 248 result = self._driver.execute_query(
#     249     query_=self._wrap_query(query, query_type),
#     250     parameters_=params,
#     251     database_=database,
#     252     result_transformer_=neo4j.Result.to_df,
#     253     bookmark_manager_=bookmark_manager,
#     254     routing_=routing,
#     255 )
#     257 self._last_bookmarks = neo4j.Bookmarks.from_raw_values(bookmark_manager.get_bookmarks())
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\driver.py:950, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     949 with session._pipelined_begin:
# --> 950     return session._run_transaction(
#     951         access_mode,
#     952         TelemetryAPI.DRIVER,
#     953         work,
#     954         (query_str, parameters, result_transformer_),
#     955         {},
#     956     )
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:566, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     565 try:
# --> 566     self._open_transaction(
#     567         tx_cls=ManagedTransaction,
#     568         api=None if telemetry_sent else api,
#     569         access_mode=access_mode,
#     570         metadata=metadata,
#     571         timeout=timeout,
#     572         api_success_cb=api_success_cb,
#     573     )
#     574     assert isinstance(self._transaction, ManagedTransaction)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:432, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     422 def _open_transaction(
#     423     self,
#     424     *,
#    (...)    430     api_success_cb: t.Callable[[dict], None] | None = None,
#     431 ) -> None:
# --> 432     self._connect(access_mode=access_mode)
#     433     assert self._connection is not None
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\session.py:128, in Session._connect(self, access_mode, **acquire_kwargs)
#     127 try:
# --> 128     super()._connect(
#     129         access_mode, auth=self._config.auth, **acquire_kwargs
#     130     )
#     131 except asyncio.CancelledError:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:166, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     165 ssr_enabled = self._pool.ssr_enabled
# --> 166 target_db = self._get_routing_target_database(
#     167     acquire_auth,
#     168     ssr_enabled=ssr_enabled,
#     169     acquisition_deadline=acquisition_deadline,
#     170 )
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:244, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled, acquisition_deadline)
#     243 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 244 self._pool.update_routing_table(
#     245     database=self._config.database,
#     246     imp_user=self._config.impersonated_user,
#     247     bookmarks=self._get_bookmarks(),
#     248     auth=acquire_auth,
#     249     acquisition_timeout=acquisition_deadline,
#     250     database_callback=self._make_db_resolution_callback(),
#     251 )
#     252 return AcquisitionDatabase(self._config.database)
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:1009, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1003     prefer_initial_routing_address = True
#    1005 if (
#    1006     prefer_initial_routing_address
#    1007     and
#    1008     # TODO: Test this state
# -> 1009     self._update_routing_table_from(
#    1010         self.address,
#    1011         database=database,
#    1012         imp_user=imp_user,
#    1013         bookmarks=bookmarks,
#    1014         auth=auth,
#    1015         acquisition_timeout=acquisition_timeout,
#    1016         database_callback=database_callback,
#    1017         ignored_errors=errors,
#    1018     )
#    1019 ):
#    1020     # Why is only the first initial routing address used?
#    1021     return
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:935, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, ignored_errors, *routers)
#     932 for address in NetworkUtil.resolve_address(
#     933     router, resolver=self.pool_config.resolver
#     934 ):
# --> 935     new_routing_table = self.fetch_routing_table(
#     936         address=address,
#     937         acquisition_timeout=acquisition_timeout,
#     938         database=database,
#     939         imp_user=imp_user,
#     940         bookmarks=bookmarks,
#     941         auth=auth,
#     942         ignored_errors=ignored_errors,
#     943     )
#     944     if new_routing_table is not None:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:833, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth, ignored_errors)
#     832 try:
# --> 833     new_routing_info = self.fetch_routing_info(
#     834         address,
#     835         database,
#     836         imp_user,
#     837         bookmarks,
#     838         auth,
#     839         acquisition_timeout,
#     840     )
#     841 except Neo4jError as e:
#     842     # checks if the code is an error that is caused by the client. In
#     843     # this case there is no sense in trying to fetch a RT from another
#     844     # router. Hence, the driver should fail fast during discovery.
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:792, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     791     auth.force_auth = False
# --> 792 cx = self._acquire(address, auth, deadline, None)
#     793 try:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     230 try:
# --> 231     connection = self.opener(
#     232         address, auth or self.pool_config.auth, deadline
#     233     )
#     234 except ServiceUnavailable:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:711, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     710 def opener(addr, auth_manager, deadline):
# --> 711     return Bolt.open(
#     712         addr,
#     713         auth_manager=auth_manager,
#     714         deadline=deadline,
#     715         routing_context=routing_context,
#     716         pool_config=pool_config,
#     717     )
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:426, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     425 try:
# --> 426     connection.hello()
#     427 finally:
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_bolt6.py:185, in Bolt6x0.hello(self, dehydration_hooks, hydration_hooks)
#     184 self.send_all()
# --> 185 self.fetch_all()
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:883, in Bolt.fetch_all(self)
#     882 while not response.complete:
# --> 883     detail_delta, summary_delta = self.fetch_message()
#     884     detail_count += detail_delta
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:868, in Bolt.fetch_message(self)
#     865 tag, fields = self.inbox.pop(
#     866     hydration_hooks=self.responses[0].hydration_hooks
#     867 )
# --> 868 res = self._process_message(tag, fields)
#     869 self.idle_since = monotonic()
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_bolt6.py:548, in Bolt6x0._process_message(self, tag, fields)
#     547 try:
# --> 548     response.on_failure(summary_metadata or {})
#     549 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:304, in LogonResponse.on_failure(self, metadata)
#     303 Util.callback(handler)
# --> 304 raise self._hydrate_error(metadata)
#
# AuthError: {neo4j_code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.} {gql_status: 42NFF} {gql_status_description: error: syntax error or access rule violation - permission/access denied. Access denied, see the security logs for details.}
#
# During handling of the above exception, another exception occurred:
#
# UnableToConnectError                      Traceback (most recent call last)
# Cell In[3], line 7
#       3 host = "neo4j://127.0.0.1:7687"
#       4 user = "neo4j"
#       5 password= "pleaseletmein"
#       6
# ----> 7 gds = GraphDataScience(host, auth=(user, password))
#       8
#       9 print(gds.version())
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\graph_data_science.py:105, in GraphDataScience.__init__(self, endpoint, auth, aura_ds, database, arrow, arrow_disable_server_verification, arrow_tls_root_certs, bookmarks, show_progress, arrow_client_options)
#     100     neo4j_query_runner = Neo4jQueryRunner.create_for_db(
#     101         endpoint, db_auth, aura_ds, database, bookmarks, show_progress
#     102     )
#     103     self._query_runner = neo4j_query_runner
# --> 105 self._server_version = self._query_runner.server_version()
#     107 if self._server_version < ServerVersion.from_string(__min_server_version__):
#     108     warnings.warn(
#     109         DeprecationWarning(
#     110             f"Client does not support the given server version `{self._server_version}`."
#    (...)    113         )
#     114     )
#
# File ~\OneDrive\Desktop\Projects\Finance Hackathon\.venv\Lib\site-packages\graphdatascience\query_runner\neo4j_query_runner.py:339, in Neo4jQueryRunner.server_version(self)
#     331     self.close()
#     333     raise GdsNotFound(
#     334         f"""The Graph Data Science library is not correctly installed on the {self._instance_description}.
#     335         Please refer to https://neo4j.com/docs/graph-data-science/current/installation/.
#     336         """
#     337     )
# --> 339 raise UnableToConnectError(e)
#
# UnableToConnectError: {neo4j_code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.} {gql_status: 42NFF} {gql_status_description: error: syntax error or access rule violation - permission/access denied. Access denied, see the security logs for details.}
